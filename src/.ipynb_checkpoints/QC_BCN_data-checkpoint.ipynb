# %% [markdown]
# # QC_bcn_dataset.py
#
# # QC on BCN dataset sent from Cornell Lab

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("BCN_eBird_data_20241004.csv", low_memory=False)

df
# Out:
#             sub_id   group_id proj_id         obs_id  \
# 0       S188388199  G12958161   EBIRD  OBS2337070979
# 1       S188388199  G12958161   EBIRD  OBS2337070980
# 2       S188388199  G12958161   EBIRD  OBS2337070981
# 3       S193260612  G12958161   EBIRD  OBS2424441575
# 4       S193260612  G12958161   EBIRD  OBS2424441576
# ...            ...        ...     ...            ...
# 244686    S5175024        NaN   EBIRD    OBS72836970
# 244687    S5175024        NaN   EBIRD    OBS72836971
# 244688    S5175024        NaN   EBIRD    OBS72836972
# 244689    S5175024        NaN   EBIRD    OBS72836973
# 244690    S5175024        NaN   EBIRD    OBS72836974
#
#                    primary_com_name orig_species_code report_as  valid  \
# 0                    Common Grackle            comgra    comgra      1
# 1                    American Robin            amerob    amerob      1
# 2                      Song Sparrow            sonspa    sonspa      1
# 3                    Common Grackle            comgra    comgra      1
# 4                    American Robin            amerob    amerob      1
# ...                             ...               ...       ...    ...
# 244686         Red-winged Blackbird            rewbla    rewbla      1
# 244687          Common Yellowthroat            comyel    comyel      1
# 244688               Common Grackle            comgra    comgra      1
# 244689               American Robin            amerob    amerob      1
# 244690  Willow Flycatcher (Eastern)           wilfly1    wilfly      1
#
#         reviewed  how_many_atleast  ...  all_obs_reported  \
# 0              0                 1  ...                 1
# 1              0                 1  ...                 1
# 2              0                 1  ...                 1
# 3              0                 1  ...                 1
# 4              0                 1  ...                 1
# ...          ...               ...  ...               ...
# 244686         0                 9  ...                 1
# 244687         0                 1  ...                 1
# 244688         0                 1  ...                 1
# 244689         0                 1  ...                 1
# 244690         1                 1  ...                 1
#
#                                              sub_comments  \
# 0       H) mid diagonal path; Humid, quiet, increased ...
# 1       H) mid diagonal path; Humid, quiet, increased ...
# 2       H) mid diagonal path; Humid, quiet, increased ...
# 3       H) mid diagonal path; Humid, quiet, increased ...
# 4       H) mid diagonal path; Humid, quiet, increased ...
# ...                                                   ...
# 244686                              64 degrees calm,sunny
# 244687                              64 degrees calm,sunny
# 244688                              64 degrees calm,sunny
# 244689                              64 degrees calm,sunny
# 244690                              64 degrees calm,sunny
#
#                          obs_dt obs_time_valid checklist_id num_observers  \
# 0       2024-07-23 10:13:00.000              1      CL23300           1.0
# 1       2024-07-23 10:13:00.000              1      CL23300           1.0
# 2       2024-07-23 10:13:00.000              1      CL23300           1.0
# 3       2024-07-23 10:13:00.000              1      CL23300           1.0
# 4       2024-07-23 10:13:00.000              1      CL23300           1.0
# ...                         ...            ...          ...           ...
# 244686  1994-06-07 06:55:00.000              1      CL25635           2.0
# 244687  1994-06-07 06:55:00.000              1      CL25635           2.0
# 244688  1994-06-07 06:55:00.000              1      CL25635           2.0
# 244689  1994-06-07 06:55:00.000              1      CL25635           2.0
# 244690  1994-06-07 06:55:00.000              1      CL25635           2.0
#
#        effort_distance_km effort_area_ha   latitude  longitude
# 0                     NaN            NaN  42.021563 -87.874341
# 1                     NaN            NaN  42.021563 -87.874341
# 2                     NaN            NaN  42.021563 -87.874341
# 3                     NaN            NaN  42.021563 -87.874341
# 4                     NaN            NaN  42.021563 -87.874341
# ...                   ...            ...        ...        ...
# 244686                NaN            NaN  42.128799 -88.391602
# 244687                NaN            NaN  42.128799 -88.391602
# 244688                NaN            NaN  42.128799 -88.391602
# 244689                NaN            NaN  42.128799 -88.391602
# 244690                NaN            NaN  42.128799 -88.391602
#
# [244691 rows x 31 columns]

# %%
df.dtypes
# Out:
# sub_id                 object
# group_id               object
# proj_id                object
# obs_id                 object
# primary_com_name       object
# orig_species_code      object
# report_as              object
# valid                   int64
# reviewed                int64
# how_many_atleast        int64
# how_many_atmost         int64
# is_birding_hotspot      int64
# obs_comments           object
# group_id.1             object
# protocol_id            object
# loc_id                 object
# name                   object
# subnational2_code      object
# subnational1_code      object
# user_id                object
# duration_hrs          float64
# all_obs_reported        int64
# sub_comments           object
# obs_dt                 object
# obs_time_valid          int64
# checklist_id           object
# num_observers         float64
# effort_distance_km    float64
# effort_area_ha        float64
# latitude              float64
# longitude             float64
# dtype: object

# %% [markdown]
# #  unique values for text (object) columns  ----------------------------------

# %%
print(df['sub_id'].unique())
# Out:
# ['S188388199' 'S193260612' 'S188386852' ... 'S5175032' 'S5175028'
#  'S5175024']

# %%
df['group_id'].unique()
# Out:
# array(['G12958161', 'G12958162', 'G12958164', ..., 'G119452', 'G119451',
#        'G119449'], dtype=object)

# %%
df['proj_id'].unique()
# Out:
# array(['EBIRD', 'EBIRD_ATL_MD_DC'], dtype=object)

# %%
df['obs_id'].unique()
# Out:
# array(['OBS2337070979', 'OBS2337070980', 'OBS2337070981', ...,
#        'OBS72836972', 'OBS72836973', 'OBS72836974'], dtype=object)

# %%
df['primary_com_name'].unique()
# Out:
# array(['Common Grackle', 'American Robin', 'Song Sparrow',
#        'White-breasted Nuthatch', 'American Crow', 'Red-winged Blackbird',
#        'American Goldfinch', 'Blue Jay', 'Red-bellied Woodpecker',
#        'Downy Woodpecker', 'Northern Flicker', 'Northern Cardinal',
#        'Black-capped Chickadee', 'Belted Kingfisher', 'Gray Catbird',
#        'House Wren', 'House Finch', 'Red-headed Woodpecker',
#        'Northern Flicker (Yellow-shafted)', 'Cedar Waxwing',
#        'Barn Swallow', 'Black-crowned Night Heron',
#        'Blue-gray Gnatcatcher', 'Turkey Vulture', 'Hairy Woodpecker',
#        'Ruby-throated Hummingbird', 'Mourning Dove', 'House Sparrow',
#        'Great Crested Flycatcher', 'Killdeer', 'Field Sparrow',
#        'Indigo Bunting', 'Yellow Warbler', 'Eastern Wood-Pewee',
#        'Orchard Oriole', 'Brown-headed Cowbird', 'Common Yellowthroat',
#        'Red-eyed Vireo', 'Eastern Towhee', 'Eastern Bluebird',
#        'Eastern Kingbird', 'Tree Swallow', 'Savannah Sparrow',
#        'Willow Flycatcher', "Cooper's Hawk", 'Tufted Titmouse',
#        'Downy/Hairy Woodpecker', 'Canada Goose', 'Scarlet Tanager',
#        'Wood Thrush', "Henslow's Sparrow", 'Bobolink', 'Great Blue Heron',
#        'Marsh Wren', 'Swamp Sparrow', 'Chimney Swift', 'Least Flycatcher',
#        'Yellow-breasted Chat', 'European Starling', 'Brown Thrasher',
#        'Cliff Swallow', 'American Redstart', 'Baltimore Oriole',
#        'Mallard', 'Rose-breasted Grosbeak', 'Warbling Vireo',
#        'Dickcissel', 'Eastern Meadowlark', 'Sedge Wren', 'Great Egret',
#        'Double-crested Cormorant', 'Eastern Phoebe', 'Red-tailed Hawk',
#        'Horned Lark', 'White-eyed Vireo', 'swallow sp.',
#        'Pileated Woodpecker', 'American Kestrel', 'Barred Owl',
#        'Loggerhead Shrike', 'Purple Martin', 'Ring-billed Gull',
#        'Grasshopper Sparrow', 'blackbird sp.', 'Bank Swallow',
#        'Spotted Sandpiper', 'Wood Duck', 'Blue Grosbeak',
#        'Sandhill Crane', 'Broad-winged Hawk', 'Chipping Sparrow',
#        'Acadian Flycatcher', 'Common Nighthawk', 'Black-billed Cuckoo',
#        "Bell's Vireo", 'Green Heron', 'Caspian Tern', 'Least Bittern',
#        'Pied-billed Grebe', 'Hooded Merganser', 'American Coot', 'Osprey',
#        'Yellow-throated Vireo', 'Red-winged Blackbird (Red-winged)',
#        'White-throated Sparrow', 'Rock Pigeon (Feral Pigeon)', 'Ovenbird',
#        'Northern Rough-winged Swallow', 'Bald Eagle',
#        'Yellow-billed Cuckoo', 'Carolina Wren', 'Great Horned Owl',
#        'Red-tailed Hawk (borealis)', 'Red-shouldered Hawk', 'Mute Swan',
#        'Veery', 'Common Gallinule', 'Sora', 'Louisiana Waterthrush',
#        'gull sp.', 'Wild Turkey', 'Virginia Rail', 'woodpecker sp.',
#        'passerine sp.', 'Herring Gull (American)',
#        'Yellow-rumped Warbler', 'Sharp-shinned Hawk',
#        'Prothonotary Warbler', 'Brown Creeper', 'Northern Parula',
#        'Summer Tanager', 'Northern Bobwhite',
#        'Eastern Meadowlark (Eastern)', 'House Wren (Northern)',
#        'Blue-winged Warbler', 'Ring-necked Pheasant',
#        'Worm-eating Warbler', 'Mallard (Domestic type)',
#        'Common Goldeneye', 'Blue-winged Teal', 'Hooded Warbler',
#        'Pine Warbler', 'American Woodcock', 'Downy Woodpecker (Eastern)',
#        'Buteo sp.', 'Northern Mockingbird', 'Black-and-white Warbler',
#        'Connecticut Warbler', 'Olive-sided Flycatcher',
#        'Tennessee Warbler', 'Nashville Warbler', 'Mourning Warbler',
#        "Swainson's Thrush", "Wilson's Warbler", 'Blackburnian Warbler',
#        'White-breasted Nuthatch (Eastern)', 'Common Grackle (Bronzed)',
#        'Peregrine Falcon', 'Chestnut-sided Warbler', 'vireo sp.',
#        'Great Blue Heron (Great Blue)', 'Prairie Warbler',
#        'new world warbler sp.', 'Gadwall', 'Trumpeter Swan',
#        'Yellow-throated Warbler', 'new world flycatcher sp.', 'hawk sp.',
#        'thrush sp.', 'Blue-headed Vireo', 'new world sparrow sp.',
#        'Vesper Sparrow', 'Clay-colored Sparrow',
#        'Song Sparrow (melodia/atlantica)', 'Western Meadowlark',
#        "Alder/Willow Flycatcher (Traill's Flycatcher)",
#        'Alder Flycatcher', 'Eastern Screech-Owl', 'Northern Harrier',
#        'American White Pelican', 'Northern Shoveler',
#        'Black-throated Green Warbler', 'Yellow-bellied Flycatcher',
#        'Northern Waterthrush', 'Solitary Sandpiper', "Wilson's Snipe",
#        'Catharus sp.', 'Semipalmated Sandpiper', 'duck sp.',
#        'White-crowned Sparrow', 'Mallard/American Black Duck',
#        'Least Sandpiper', 'wren sp.', 'American Bittern', 'Empidonax sp.',
#        'dabbling duck sp.', 'Yellow-billed/Black-billed Cuckoo',
#        'shorebird sp.', 'Red-breasted Nuthatch', 'Upland Sandpiper',
#        'Philadelphia Vireo', 'Lesser Yellowlegs', 'Winter Wren',
#        'King Rail', 'Western/Eastern Meadowlark',
#        'Marsh Wren (palustris Group)', 'Ring-necked Duck',
#        'Cerulean Warbler', 'Hairy Woodpecker (Eastern)',
#        'Warbling Vireo (Eastern)', 'Blue-gray Gnatcatcher (caerulea)',
#        'goose sp.', 'Black Rail', 'Canada Goose (moffitti/maxima)',
#        'Yellow Warbler (Northern)', 'Spizella sp.', 'Kentucky Warbler',
#        'Lark Sparrow', 'Barn Swallow (American)',
#        'Savannah Sparrow (Savannah)', 'tanager sp. (Piranga sp.)',
#        'Ruddy Duck', 'Semipalmated Plover', 'Snowy Egret',
#        'Rusty Blackbird', 'Philadelphia/Warbling Vireo', 'Monk Parakeet',
#        'Black Tern', 'Eastern Whip-poor-will', 'Accipiter sp.',
#        'Red-breasted Merganser', 'new world oriole sp.',
#        'Orange-crowned Warbler', 'Black-bellied Plover/golden-plover sp.',
#        'American Coot (Red-shielded)', "Forster's Tern",
#        "Brewer's Blackbird", 'Yellow-headed Blackbird', 'Long-eared Owl',
#        'Ruby-crowned Kinglet', "LeConte's Sparrow", "Lincoln's Sparrow",
#        'Northern Pintail', 'Graylag Goose (Domestic type)',
#        'American Tree Sparrow', 'peep sp.', 'Blackpoll Warbler',
#        'Willow Flycatcher (Eastern)', 'Western Cattle Egret',
#        'Green-winged Teal (American)', 'European Goldfinch',
#        "Nelson's Sparrow", 'Eastern Towhee (Red-eyed)',
#        'American Robin (migratorius Group)', 'Yellow-bellied Sapsucker',
#        'Purple Martin (subis/arboricola)', 'Hermit Thrush',
#        "Wilson's Phalarope", "Nelson's Sparrow (Interior)",
#        'Western Kingbird', 'Canada Warbler', 'Carolina Chickadee',
#        'Scissor-tailed Flycatcher', 'Common Tern', 'Fox Sparrow',
#        'American Wigeon', 'Common Merganser'], dtype=object)

# %%
df['orig_species_code'].unique()
# Out:
# array(['comgra', 'amerob', 'sonspa', 'whbnut', 'amecro', 'rewbla',
#        'amegfi', 'blujay', 'rebwoo', 'dowwoo', 'norfli', 'norcar',
#        'bkcchi', 'belkin1', 'grycat', 'houwre', 'houfin', 'rehwoo',
#        'yesfli', 'cedwax', 'barswa', 'bcnher', 'buggna', 'turvul',
#        'haiwoo', 'rthhum', 'moudov', 'houspa', 'grcfly', 'killde',
#        'fiespa', 'indbun', 'yelwar', 'eawpew', 'orcori', 'bnhcow',
#        'comyel', 'reevir1', 'eastow', 'easblu', 'easkin', 'treswa',
#        'savspa', 'wilfly', 'coohaw', 'tuftit', 'y00322', 'cangoo',
#        'scatan', 'woothr', 'henspa', 'boboli', 'grbher3', 'marwre',
#        'swaspa', 'chiswi', 'leafly', 'yebcha', 'eursta', 'brnthr',
#        'cliswa', 'amered', 'balori', 'mallar3', 'robgro', 'warvir',
#        'dickci', 'easmea', 'sedwre1', 'greegr', 'doccor', 'easpho',
#        'rethaw', 'horlar', 'whevir', 'swallo', 'pilwoo', 'amekes',
#        'brdowl', 'logshr', 'purmar', 'ribgul', 'graspa', 'blackb',
#        'banswa', 'sposan', 'wooduc', 'blugrb1', 'sancra', 'brwhaw',
#        'chispa', 'acafly', 'comnig', 'bkbcuc', 'belvir', 'grnher',
#        'caster1', 'leabit', 'pibgre', 'hoomer', 'y00475', 'osprey',
#        'yetvir', 'rewbla1', 'whtspa', 'rocpig1', 'ovenbi1', 'nrwswa',
#        'baleag', 'yebcuc', 'carwre', 'grhowl', 'erthaw1', 'reshaw',
#        'mutswa', 'veery', 'comgal1', 'sora', 'louwat', 'larus', 'wiltur',
#        'virrai', 'woodpe1', 'passer1', 'amhgul1', 'yerwar', 'shshaw',
#        'prowar', 'brncre', 'norpar', 'sumtan', 'norbob', 'easmea2',
#        'houwre1', 'buwwar', 'rinphe1', 'woewar1', 'mallar2', 'comgol',
#        'buwtea', 'hoowar', 'pinwar', 'amewoo', 'dowwoo1', 'buteo',
#        'normoc', 'bawwar', 'conwar', 'olsfly', 'tenwar', 'naswar',
#        'mouwar', 'swathr', 'wlswar', 'bkbwar', 'whbnut2', 'comgra2',
#        'perfal', 'chswar', 'vireo1', 'grbher', 'prawar', 'warble',
#        'gadwal', 'truswa', 'yetwar', 'flycat1', 'hawk', 'thrush1',
#        'buhvir', 'sparro1', 'vesspa', 'clcspa', 'sonspa2', 'wesmea',
#        'y00324', 'aldfly', 'easowl1', 'norhar2', 'amwpel', 'norsho',
#        'btnwar', 'yebfly', 'norwat', 'solsan', 'wilsni1', 'cathus',
#        'semsan', 'duck1', 'whcspa', 'y00600', 'leasan', 'wren1', 'amebit',
#        'empido', 'dabduc1', 'y00616', 'shoreb1', 'rebnut', 'uplsan',
#        'phivir', 'lesyel', 'winwre3', 'kinrai4', 'meadow', 'marwre3',
#        'rinduc', 'cerwar', 'haiwoo2', 'eawvir1', 'buggna1', 'goose1',
#        'blkrai', 'cangoo4', 'yelwar1', 'spizel1', 'kenwar', 'larspa',
#        'barswa5', 'savspa4', 'pirang1', 'rudduc', 'semplo', 'snoegr',
#        'rusbla', 'y00704', 'monpar', 'blkter', 'easwpw1', 'accipi',
#        'rebmer', 'oriole', 'orcwar', 'y00494', 'amecoo', 'forter',
#        'brebla', 'yehbla', 'loeowl', 'ruckin', 'lecspa', 'linspa',
#        'norpin', 'gragoo1', 'amtspa', 'calidr', 'bkpwar', 'wilfly1',
#        'categr1', 'agwtea1', 'eurgol', 'nstspa', 'eastow1', 'amerob1',
#        'yebsap', 'purmar1', 'herthr', 'wilpha', 'nstspa1', 'weskin',
#        'canwar', 'carchi', 'sctfly', 'comter', 'foxspa', 'amewig',
#        'commer'], dtype=object)

# %%
df['report_as'].unique()
# Out:
# array(['comgra', 'amerob', 'sonspa', 'whbnut', 'amecro', 'rewbla',
#        'amegfi', 'blujay', 'rebwoo', 'dowwoo', 'norfli', 'norcar',
#        'bkcchi', 'belkin1', 'grycat', 'houwre', 'houfin', 'rehwoo',
#        'cedwax', 'barswa', 'bcnher', 'buggna', 'turvul', 'haiwoo',
#        'rthhum', 'moudov', 'houspa', 'grcfly', 'killde', 'fiespa',
#        'indbun', 'yelwar', 'eawpew', 'orcori', 'bnhcow', 'comyel',
#        'reevir1', 'eastow', 'easblu', 'easkin', 'treswa', 'savspa',
#        'wilfly', 'coohaw', 'tuftit', 'y00322', 'cangoo', 'scatan',
#        'woothr', 'henspa', 'boboli', 'grbher3', 'marwre', 'swaspa',
#        'chiswi', 'leafly', 'yebcha', 'eursta', 'brnthr', 'cliswa',
#        'amered', 'balori', 'mallar3', 'robgro', 'warvir', 'dickci',
#        'easmea', 'sedwre1', 'greegr', 'doccor', 'easpho', 'rethaw',
#        'horlar', 'whevir', 'swallo', 'pilwoo', 'amekes', 'brdowl',
#        'logshr', 'purmar', 'ribgul', 'graspa', 'blackb', 'banswa',
#        'sposan', 'wooduc', 'blugrb1', 'sancra', 'brwhaw', 'chispa',
#        'acafly', 'comnig', 'bkbcuc', 'belvir', 'grnher', 'caster1',
#        'leabit', 'pibgre', 'hoomer', 'y00475', 'osprey', 'yetvir',
#        'whtspa', 'rocpig', 'ovenbi1', 'nrwswa', 'baleag', 'yebcuc',
#        'carwre', 'grhowl', 'reshaw', 'mutswa', 'veery', 'comgal1', 'sora',
#        'louwat', 'larus', 'wiltur', 'virrai', 'woodpe1', 'passer1',
#        'hergul', 'yerwar', 'shshaw', 'prowar', 'brncre', 'norpar',
#        'sumtan', 'norbob', 'buwwar', 'rinphe1', 'woewar1', 'comgol',
#        'buwtea', 'hoowar', 'pinwar', 'amewoo', 'buteo', 'normoc',
#        'bawwar', 'conwar', 'olsfly', 'tenwar', 'naswar', 'mouwar',
#        'swathr', 'wlswar', 'bkbwar', 'perfal', 'chswar', 'vireo1',
#        'prawar', 'warble', 'gadwal', 'truswa', 'yetwar', 'flycat1',
#        'hawk', 'thrush1', 'buhvir', 'sparro1', 'vesspa', 'clcspa',
#        'wesmea', 'y00324', 'aldfly', 'easowl1', 'norhar2', 'amwpel',
#        'norsho', 'btnwar', 'yebfly', 'norwat', 'solsan', 'wilsni1',
#        'cathus', 'semsan', 'duck1', 'whcspa', 'y00600', 'leasan', 'wren1',
#        'amebit', 'empido', 'dabduc1', 'y00616', 'shoreb1', 'rebnut',
#        'uplsan', 'phivir', 'lesyel', 'winwre3', 'kinrai4', 'meadow',
#        'rinduc', 'cerwar', 'goose1', 'blkrai', 'spizel1', 'kenwar',
#        'larspa', 'pirang1', 'rudduc', 'semplo', 'snoegr', 'rusbla',
#        'y00704', 'monpar', 'blkter', 'easwpw1', 'accipi', 'rebmer',
#        'oriole', 'orcwar', 'y00494', 'forter', 'brebla', 'yehbla',
#        'loeowl', 'ruckin', 'lecspa', 'linspa', 'norpin', 'gragoo',
#        'amtspa', 'calidr', 'bkpwar', 'categr1', 'gnwtea', 'eurgol',
#        'nstspa', 'yebsap', 'herthr', 'wilpha', 'weskin', 'canwar',
#        'carchi', 'sctfly', 'comter', 'foxspa', 'amewig', 'commer'],
#       dtype=object)

# %%
df['obs_comments'].unique()
# Out:
# array([nan, 'one feeding at base of tree in the wet area south',
#        'heard once', ..., 'P,CN,S', '7Y',
#        'Exhibiting territorial behavior'], dtype=object)

# %%
df['group_id.1'].unique()
# Out:
# array(['G12958161', 'G12958162', 'G12958164', ..., 'G119452', 'G119451',
#        'G119449'], dtype=object)

# %%
df['protocol_id'].unique()
# Out:
# array(['P87'], dtype=object)

# %%
df['loc_id'].unique()
# Out:
# array(['L36118300', 'L36118341', 'L36120049', ..., 'L1779270', 'L1778761',
#        'L1779266'], dtype=object)

# %%
df['name'].unique()
# Out:
# array(['Izaak Walton - Des Plaines H) SA01',
#        'Izaak Walton - Des Plaines G) SA01',
#        'Izaak Walton - Des Plaines F1) SA01 Mid Path', ...,
#        'Mallard Lake--P18', 'Churchill Woods--P2A', 'Mallard Lake--P9'],
#       dtype=object)

# %%
df['subnational2_code'].unique()
# Out:
# array(['US-IL-031', 'US-IL-043', 'US-IL-111', 'US-IL-037', 'US-IL-089',
#        'US-IL-097', 'US-IL-197', 'US-IL-063', 'US-IL-093'], dtype=object)

# %%
df['subnational1_code'].unique()
# Out:
# array(['US-IL'], dtype=object)

# %%
df['user_id'].unique()
# Out:
# array(['USER1151', 'USER912612', 'USER11024', 'USER514405', 'USER446039',
#        'USER1641733', 'USER1705438', 'USER515761', 'USER409317',
#        'USER336214', 'USER544221', 'USER88919', 'USER332575',
#        'USER572859', 'USER924912', 'USER329079', 'USER103498',
#        'USER686370', 'USER339609', 'USER31420', 'USER124129',
#        'USER180233', 'USER226512', 'USER1543697', 'USER449068',
#        'USER106714', 'USER142163', 'USER146134', 'USER389749',
#        'USER513531', 'USER439155', 'USER519101', 'USER413096',
#        'USER3532366', 'USER1171095', 'USER110401', 'USER1116328',
#        'USER17440', 'USER1396701', 'USER343628', 'USER1081976',
#        'USER659632', 'USER1371737', 'USER2968456', 'USER2194395',
#        'USER376656', 'USER1686951', 'USER1177494', 'USER306693',
#        'USER256962', 'USER15643', 'USER1231798', 'USER402041',
#        'USER123174', 'USER443265', 'USER1478925', 'USER1356595',
#        'USER1226581', 'USER1145683', 'USER431029', 'USER421890',
#        'USER216456', 'USER582669', 'USER105600', 'USER137807',
#        'USER217894', 'USER248199', 'USER773988', 'USER686358',
#        'USER1397056', 'USER265266', 'USER399402', 'USER473707',
#        'USER584384', 'USER773360', 'USER298126', 'USER1452441',
#        'USER2374837', 'USER33357', 'USER134669', 'USER129848',
#        'USER905006', 'USER272024', 'USER1055696', 'USER15930',
#        'USER136647', 'USER271837', 'USER455300', 'USER111450',
#        'USER184235', 'USER526039', 'USER326014', 'USER103146',
#        'USER801850', 'USER1105719', 'USER4573053', 'USER606667',
#        'USER90530', 'USER218525', 'USER1598063', 'USER673872',
#        'USER603799', 'USER2916', 'USER1277008', 'USER686739',
#        'USER480673', 'USER178245', 'USER3836748', 'USER1446245',
#        'USER168927', 'USER310535', 'USER1057392', 'USER189217',
#        'USER1268275', 'USER34033', 'USER19375', 'USER2754027',
#        'USER621306', 'USER242214', 'USER1338248', 'USER4020530',
#        'USER509115', 'USER1130218', 'USER208428', 'USER91149',
#        'USER562448', 'USER3384278', 'USER320619', 'USER2793771',
#        'USER2359488', 'USER223138', 'USER1822798', 'USER919660',
#        'USER36519', 'USER17624', 'USER265883', 'USER1791864',
#        'USER553183', 'USER515630', 'USER280705', 'USER387953',
#        'USER516841', 'USER1138443', 'USER90711', 'USER1064895',
#        'USER497541', 'USER1207817', 'USER956053', 'USER535280',
#        'USER11027', 'USER2480129', 'USER3730375', 'USER11014',
#        'USER1466553', 'USER355120', 'USER243780', 'USER3296339',
#        'USER117648', 'USER15928', 'USER1657718', 'USER2875721',
#        'USER435630', 'USER1957569', 'USER3222566', 'USER1301934',
#        'USER326314', 'USER123271', 'USER309778', 'USER400640',
#        'USER1048020', 'USER628917', 'USER202396', 'USER744749',
#        'USER204870', 'USER103949', 'USER11009', 'USER1005070',
#        'USER400371', 'USER155922', 'USER198039', 'USER255858',
#        'USER2503159', 'USER16073', 'USER940813', 'USER325753',
#        'USER311952', 'USER543834', 'USER556972', 'USER622853',
#        'USER1118960', 'USER559300', 'USER607938', 'USER14689',
#        'USER55667', 'USER188774', 'USER845838', 'USER414953',
#        'USER149025', 'USER409253', 'USER1118572', 'USER14042',
#        'USER185482', 'USER369606', 'USER280529', 'USER424136',
#        'USER1078307', 'USER1606326', 'USER289153', 'USER525283',
#        'USER418156', 'USER56788', 'USER400301', 'USER740973',
#        'USER213429', 'USER339328', 'USER276380', 'USER309761',
#        'USER894252', 'USER417585', 'USER924572', 'USER162144',
#        'USER691649', 'USER934037', 'USER659476', 'USER533459',
#        'USER773738', 'USER729080', 'USER154066', 'USER187520',
#        'USER613919', 'USER186627', 'USER751457', 'USER119876',
#        'USER222736', 'USER189813', 'USER35481', 'USER35065', 'USER222607',
#        'USER207861', 'USER397921', 'USER216642', 'USER151980',
#        'USER97529', 'USER146658', 'USER267405', 'USER56503', 'USER17625',
#        'USER527704', 'USER55987', 'USER322997', 'USER31311', 'USER16428',
#        'USER343734', 'USER417971', 'USER129882', 'USER411482',
#        'USER213233', 'USER276396', 'USER86560', 'USER276382', 'USER33081',
#        'USER340749', 'USER155941', 'USER244230', 'USER18573', 'USER11080',
#        'USER28258', 'USER114260', 'USER151447', 'USER219599',
#        'USER155985', 'USER106049', 'USER188083', 'USER204829',
#        'USER16414', 'USER154289', 'USER129696', 'USER186641',
#        'USER194293', 'USER31449', 'USER11104', 'USER163163', 'USER11098',
#        'USER86388', 'USER17421', 'USER32713', 'USER1117', 'USER33139',
#        'USER17117', 'USER86516', 'USER29289', 'USER56739', 'USER41664',
#        'USER16247', 'USER17020', 'USER1010', 'USER4346', 'USER17027',
#        'USER9159', 'USER15924', 'USER33123', 'USER33141', 'USER15927',
#        'USER15784', 'USER11086', 'USER11010', 'USER33145', 'USER11084',
#        'USER33137', 'USER11087', 'USER11041'], dtype=object)

# %%
df['sub_comments'].unique()
# Out:
# array(['H) mid diagonal path; Humid, quiet, increased mosquitoes, 79 degrees, sunny',
#        "G) SA01 east river edge at far south end of path; very wet and muddy so had to watch step and couldn't walk as far south as previously; 79 degrees, sunny, similar wind to prior",
#        'FB: SA01, half way between F and G, along river and wood duck house, 78 degrees sunny.  Muddy slippery path.',
#        ..., '64 degrees clm,sunny', '64 degrees sunny calm',
#        '64 degrees calm,sunny'], dtype=object)

# %% [markdown]
# # unique values for date / time (object) -----------------------

# %%
df['obs_dt'].unique()
# Out:
# array(['2024-07-23 10:13:00.000', '2024-07-23 09:59:00.000',
#        '2024-07-23 09:46:00.000', ..., '1994-06-07 08:10:00.000',
#        '1994-06-07 07:10:00.000', '1994-06-07 06:55:00.000'], dtype=object)

# %% [markdown]
# # true / false  (integer) --------------------------

# %%
df['all_obs_reported'].unique()
# Out:
# array([1, 0])

# %%
df['obs_time_valid'].unique()
# Out:
# array([1, 0])

# %%
df['valid'].unique()
# Out:
# array([1, 0])

# %%
df['reviewed'].unique()
# Out:
# array([0, 1])

# %%
df['reviewed'].unique()
# Out:
# array([0, 1])

# %%
df['is_birding_hotspot'].unique()
# Out:
# array([0, 1])

# %%
df['all_obs_reported'].unique()
# Out:
# array([1, 0])

# %%
df['obs_time_valid'].unique()
# Out:
# array([1, 0])

# %% [markdown]
# # integer -----------------------

# %%
df['how_many_atleast'].unique()
# Out:
# array([  1,   2,   6,   3,   5,   4,   9,  10,  15,  11,   8,  25,   7,
#         13,  21,  17,  26,  12,  20,  14, 300,  28,  76,  37,  40,  18,
#         52,  16,  30,  44,  29, 125,  55,  19,  27,  85,  34,  63,  32,
#         24,  45,  65,  31,  75,  22,  60,  23,  47,  39,  42,  90,  53,
#         33,  41,  50,  35,  38,  36,  54, 120,  43,  71,  70,  78, 107,
#         48,  49,  58,  57, 100,  80,  92,  59, 150, 200, 204,  46,  56,
#         64, 104, 400])

# %%
df['how_many_atmost'].unique()
# the value 999999999 value must be an error
# Out:
# array([        1,         2,         6,         3,         5,         4,
#                9,        10,        15,        11,         8,        25,
#                7,        13,        21,        17,        26,        12,
#               20,        14,       300,        28,        76,        37,
#               40,        18,        52,        16,        30,        44,
#               29,       125, 999999999,        55,        19,        27,
#               85,        34,        63,        32,        24,        45,
#               65,        31,        75,        22,        60,        23,
#               47,        39,        42,        90,        53,        33,
#               41,        50,        35,        38,        36,        54,
#              120,        43,        71,        70,        78,       107,
#               48,        49,        58,        57,       100,        80,
#               92,        59,       150,       200,       204,        46,
#               56,        64,       104,       400])

# %% [markdown]
# # float  ---------------------

# %%
df['duration_hrs'].unique()
# Out:
# array([0.133, 0.233, 0.183, 0.15 , 0.2  , 0.117, 0.1  , 2.5  , 0.084,
#        0.083, 0.067, 0.05 , 0.25 , 0.3  , 0.333, 0.217, 0.167, 1.883,
#        0.134, 0.267, 1.6  , 0.75 , 1.5  , 1.   , 0.283, 1.417, 0.184,
#        1.617, 2.583, 0.317, 0.35 , 0.033, 1.733, 0.45 , 0.65 ,   nan,
#        0.884, 2.417, 0.667, 0.7  , 0.5  , 5.   , 1.25 , 2.467, 0.417,
#        2.867, 0.234, 3.017, 2.833, 1.333, 0.617, 0.4  , 0.85 , 0.55 ,
#        0.017])

# %%
df['duration_hrs'].plot(kind='hist', bins=100, color='skyblue', edgecolor='black')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.show()

# %%
df['num_observers'].unique()
# Out:
# array([ 1.,  2.,  3.,  5., nan,  4., 21.])

# %%
df['num_observers'].plot(kind='hist', bins=100, color='skyblue', edgecolor='black')
plt.xlabel('No. Observers')
plt.ylabel('Frequency')
plt.show()

# %%
df['effort_distance_km'].unique()
# Out:
# array([  nan, 0.322, 0.   , 0.161, 1.609, 3.862, 3.621, 0.31 , 0.2  ,
#        0.25 , 0.13 , 4.007, 0.75 , 5.407, 5.568, 5.552])

# %%
df['effort_distance_km'].plot(kind='hist', bins=100, color='skyblue', edgecolor='black')
plt.xlabel('distance km')
plt.ylabel('Frequency')
plt.show()

# %%
df['effort_area_ha'].unique()
# Out:
# array([         nan, 2.589990e+01, 4.047000e-01, 4.046860e+01,
#        2.180000e+00, 8.094000e-01, 1.214100e+00, 2.023400e+00,
#        1.618700e+00, 3.642200e+00, 2.428100e+00, 1.770000e+00,
#        7.163000e-01, 1.294994e+02, 1.000000e-02, 1.500000e+00,
#        6.000000e+01, 1.456900e+00])

# %%
df['effort_area_ha'].plot(kind='hist', bins=100, color='skyblue', edgecolor='black')
plt.xlabel('area ha')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# # spatial (float) --------------------------

# %%
df['latitude'].unique()
# Out:
# array([42.0215634, 42.0213861, 42.0220682, ..., 41.95731  , 41.89139  ,
#        41.96037  ])

# %%
df['longitude'].unique()
# Out:
# array([-87.8743409, -87.8736693, -87.8744237, ..., -88.13169  ,
#        -88.04199  , -88.13516  ])

# %%
plt.plot(df['longitude'], df['latitude'], marker='o', linestyle='-', color='b') 
plt.xlabel('longitude')
plt.ylabel('latitude')
plt.show()

# %%
# see spatial coordinates plotted in Power BI
